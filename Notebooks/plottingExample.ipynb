# %%
import matplotlib.pyplot as plt
import math

# %%
x = (1, 2, 3, 4, 5, 6)
#x = tuple(range(-20, 20))
y = tuple(math.cos(i) for i in x)

# %%
plt.plot(x, y)

# %%
x = (1, 2, 3, 12)
y = (3,4,5, 90)
plt.scatter(x, y)
