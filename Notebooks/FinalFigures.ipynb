# %%
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
# Out:
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
import matplotlib.style
import matplotlib as mpl
mpl.style.use('ggplot')

# %%
# hetero
code = 'P54784'
pdb='1zhi_A'
shan = pd.read_table('../Data/Heteromers/'+code+'.shannon')
rate = pd.read_table('../Data/Heteromers/'+code+'.rate')
data = pd.concat([shan, rate], axis=1)


surf = pd.read_table('../Data/Heteromers/surface/1zhi_A.surf')
intr = pd.read_table('../Data/Heteromers/1zhi.interfaces')

dataDic = {}
for i in data['pos'].index:
    dataDic[data.iloc[i]['pos']] = (data.iloc[i]['entropy'], data.iloc[i]['norm'])
surfDic = {} 
for i in surf['pos'].index:
    surfDic[surf.iloc[i]['pos']] = (surf.iloc[i]['surface'])

inter = set(intr['pos'])

surfHist = tuple(dataDic[i][0] for i in surfDic if surfDic[i] == 1 and i in dataDic and i not in inter)
coreHist = tuple(dataDic[i][0] for i in surfDic if surfDic[i] == 0 and i in dataDic and i not in inter)
intrHist = tuple(dataDic[i][0] for i in surfDic if i in inter)

import matplotlib.pyplot as plt
import numpy as np

data_to_plot = (surfHist, coreHist, intrHist)
# Create a figure instance
fig = plt.figure(1, figsize=(9, 6))


plt.rcParams['lines.linewidth']=3
plt.rcParams['axes.facecolor']='white'
plt.rcParams['xtick.color']='gray'

# Create an axes instance
ax = fig.add_subplot(111)

# Create the boxplot
bp = ax.boxplot(data_to_plot, showfliers=False, patch_artist=True)

for cap in bp['caps']:
    cap.set(color='grey', linewidth=2)

colors = ('#FFB900', '#F78200', '#E23838')
for patch, color in zip(bp['boxes'], colors):
        patch.set_facecolor(color)
        
## change color and linewidth of the medians
for median in bp['medians']:
    median.set(color='#7f7f7f', linewidth=2)
plt.xticks((1, 2, 3), ['surface', 'core', 'interface'])
plt.ylabel("Shannon's Entropy")
plt.title('P54784')

# Save the figure
fig.savefig('p54784_box_shannon.png', bbox_inches='tight')
plt.show()


surfHist = tuple(dataDic[i][1] for i in surfDic if surfDic[i] == 1 and i in dataDic and i not in inter)
coreHist = tuple(dataDic[i][1] for i in surfDic if surfDic[i] == 0 and i in dataDic and i not in inter)
intrHist = tuple(dataDic[i][1] for i in surfDic if i in inter)


data_to_plot = (surfHist, coreHist, intrHist)
# Create a figure instance
fig = plt.figure(1, figsize=(9, 6))


plt.rcParams['lines.linewidth']=3
plt.rcParams['axes.facecolor']='white'
plt.rcParams['xtick.color']='gray'

# Create an axes instance
ax = fig.add_subplot(111)

# Create the boxplot
bp = ax.boxplot(data_to_plot, showfliers=False, patch_artist=True)

for cap in bp['caps']:
    cap.set(color='grey', linewidth=2)

colors = ('#FFB900', '#F78200', '#E23838')
for patch, color in zip(bp['boxes'], colors):
        patch.set_facecolor(color)
        
## change color and linewidth of the medians
for median in bp['medians']:
    median.set(color='#7f7f7f', linewidth=2)
plt.xticks((1, 2, 3), ['surface', 'core', 'interface'])
plt.ylabel('Evolution Rate')
plt.title('P54784')

# Save the figure
fig.savefig('p54784_box_ratio.png', bbox_inches='tight')
plt.show()

fig = plt.figure(1, figsize=(9, 6))
x = data["norm"]
y = data["entropy"]
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
lx = np.arange(start=min(x), stop=max(x+0.5), step=len(x)/1000)
ly = tuple(slope*i + intercept for i in lx)
plt.scatter(x,y, color='#3a3a3a')
plt.plot()
plt.plot(lx, ly, color='firebrick')
plt.title(code)
plt.xlabel('Evolution Rate')
plt.ylabel("Shannon's entropy")
fig.savefig('p54784_scatter.png', bbox_inches='tight')
plt.show()

#for i in inter:
#    print('color firebrick, resi', i)

for i in surfDic:
    if surfDic[i] == 1:
        print('color yelloworange, resi', i)
    elif surfDic[i] == 0 :
        print('color tv_orange, resi', i)
# Out:
# color yelloworange, resi 10
# color tv_orange, resi 11
# color yelloworange, resi 12
# color yelloworange, resi 13
# color yelloworange, resi 14
# color yelloworange, resi 15
# color tv_orange, resi 16
# color yelloworange, resi 17
# color yelloworange, resi 18
# color yelloworange, resi 19
# color yelloworange, resi 20
# color yelloworange, resi 21
# color yelloworange, resi 22
# color yelloworange, resi 23
# color yelloworange, resi 24
# color yelloworange, resi 25
# color yelloworange, resi 26
# color yelloworange, resi 37
# color yelloworange, resi 38
# color yelloworange, resi 39
# color tv_orange, resi 40
# color tv_orange, resi 41
# color tv_orange, resi 42
# color yelloworange, resi 43
# color yelloworange, resi 44
# color yelloworange, resi 45
# color yelloworange, resi 46
# color yelloworange, resi 47
# color yelloworange, resi 48
# color yelloworange, resi 49
# color tv_orange, resi 50
# color yelloworange, resi 51
# color yelloworange, resi 52
# color yelloworange, resi 53
# color yelloworange, resi 54
# color tv_orange, resi 55
# color tv_orange, resi 56
# color tv_orange, resi 57
# color tv_orange, resi 58
# color yelloworange, resi 59
# color yelloworange, resi 60
# color yelloworange, resi 61
# color yelloworange, resi 62
# color yelloworange, resi 63
# color yelloworange, resi 64
# color yelloworange, resi 65
# color tv_orange, resi 66
# color tv_orange, resi 67
# color tv_orange, resi 68
# color tv_orange, resi 69
# color tv_orange, resi 70
# color tv_orange, resi 71
# color tv_orange, resi 72
# color yelloworange, resi 73
# color yelloworange, resi 74
# color yelloworange, resi 75
# color yelloworange, resi 76
# color yelloworange, resi 77
# color yelloworange, resi 78
# color yelloworange, resi 79
# color yelloworange, resi 80
# color yelloworange, resi 81
# color yelloworange, resi 82
# color yelloworange, resi 83
# color yelloworange, resi 84
# color tv_orange, resi 85
# color tv_orange, resi 86
# color tv_orange, resi 87
# color tv_orange, resi 88
# color tv_orange, resi 89
# color tv_orange, resi 90
# color tv_orange, resi 91
# color tv_orange, resi 92
# color tv_orange, resi 93
# color yelloworange, resi 94
# color yelloworange, resi 95
# color yelloworange, resi 96
# color tv_orange, resi 97
# color tv_orange, resi 98
# color tv_orange, resi 99
# color yelloworange, resi 100
# color tv_orange, resi 101
# color tv_orange, resi 102
# color yelloworange, resi 103
# color yelloworange, resi 104
# color yelloworange, resi 105
# color yelloworange, resi 106
# color yelloworange, resi 107
# color yelloworange, resi 108
# color tv_orange, resi 109
# color yelloworange, resi 110
# color yelloworange, resi 111
# color yelloworange, resi 112
# color yelloworange, resi 113
# color yelloworange, resi 114
# color yelloworange, resi 115
# color yelloworange, resi 116
# color yelloworange, resi 117
# color yelloworange, resi 118
# color tv_orange, resi 119
# color yelloworange, resi 120
# color yelloworange, resi 121
# color yelloworange, resi 122
# color yelloworange, resi 123
# color yelloworange, resi 124
# color yelloworange, resi 125
# color yelloworange, resi 126
# color yelloworange, resi 127
# color yelloworange, resi 128
# color yelloworange, resi 129
# color tv_orange, resi 130
# color tv_orange, resi 131
# color tv_orange, resi 132
# color tv_orange, resi 133
# color tv_orange, resi 134
# color tv_orange, resi 135
# color yelloworange, resi 136
# color yelloworange, resi 137
# color yelloworange, resi 138
# color tv_orange, resi 139
# color yelloworange, resi 140
# color tv_orange, resi 141
# color yelloworange, resi 142
# color yelloworange, resi 143
# color yelloworange, resi 144
# color yelloworange, resi 145
# color yelloworange, resi 146
# color yelloworange, resi 147
# color tv_orange, resi 148
# color yelloworange, resi 149
# color tv_orange, resi 150
# color yelloworange, resi 151
# color tv_orange, resi 152
# color tv_orange, resi 153
# color yelloworange, resi 154
# color yelloworange, resi 155
# color yelloworange, resi 156
# color yelloworange, resi 157
# color tv_orange, resi 158
# color yelloworange, resi 159
# color yelloworange, resi 160
# color yelloworange, resi 161
# color yelloworange, resi 162
# color yelloworange, resi 163
# color yelloworange, resi 164
# color yelloworange, resi 165
# color yelloworange, resi 166
# color yelloworange, resi 167
# color yelloworange, resi 168
# color yelloworange, resi 169
# color tv_orange, resi 170
# color tv_orange, resi 171
# color tv_orange, resi 172
# color tv_orange, resi 173
# color yelloworange, resi 174
# color tv_orange, resi 175
# color tv_orange, resi 176
# color tv_orange, resi 177
# color tv_orange, resi 178
# color yelloworange, resi 179
# color yelloworange, resi 180
# color tv_orange, resi 181
# color yelloworange, resi 182
# color yelloworange, resi 183
# color tv_orange, resi 184
# color yelloworange, resi 185
# color yelloworange, resi 186
# color yelloworange, resi 187
# color yelloworange, resi 188
# color tv_orange, resi 189
# color yelloworange, resi 190
# color yelloworange, resi 191
# color yelloworange, resi 192
# color tv_orange, resi 193
# color yelloworange, resi 194
# color yelloworange, resi 195
# color tv_orange, resi 196
# color yelloworange, resi 197
# color yelloworange, resi 198
# color yelloworange, resi 199
# color yelloworange, resi 200
# color yelloworange, resi 201
# color yelloworange, resi 202
# color yelloworange, resi 203
# color tv_orange, resi 204
# color yelloworange, resi 205
# color yelloworange, resi 206
# color yelloworange, resi 207
# color tv_orange, resi 208
# color tv_orange, resi 209
# color yelloworange, resi 210
# color yelloworange, resi 211
# color tv_orange, resi 212
# color yelloworange, resi 213
# color yelloworange, resi 214

# %%
code = 'O75874'
pdb='4kzo_A'

shan = pd.read_table('../Data/Homomers/'+code+'.shannon')
rate = pd.read_table('../Data/Homomers/'+code+'.rate')
data = pd.concat([shan, rate], axis=1)

surf = pd.read_table('../Data/Homomers/Surface/'+pdb+'.surf')

intr = pd.read_table('../Data/Homomers/4kzo.interfaces')


dataDic = {}
for i in data['pos'].index:
    dataDic[data.iloc[i]['pos']] = (data.iloc[i]['entropy'], data.iloc[i]['norm'])
surfDic = {} 
for i in surf['pos'].index:
    surfDic[surf.iloc[i]['pos']] = (surf.iloc[i]['surface'])
    
inter = set(intr['pos'])


surfHist = tuple(dataDic[i][0] for i in surfDic if surfDic[i] == 1 and i in dataDic and i not in inter)
coreHist = tuple(dataDic[i][0] for i in surfDic if surfDic[i] == 0 and i in dataDic and i not in inter)
intrHist = tuple(dataDic[i][0] for i in surfDic if i in inter)

data_to_plot = (surfHist, coreHist, intrHist)
# Create a figure instance
fig = plt.figure(1, figsize=(9, 6))


plt.rcParams['lines.linewidth']=3
plt.rcParams['axes.facecolor']='white'
plt.rcParams['xtick.color']='gray'

# Create an axes instance
ax = fig.add_subplot(111)

# Create the boxplot
bp = ax.boxplot(data_to_plot, showfliers=False, patch_artist=True)

for cap in bp['caps']:
    cap.set(color='grey', linewidth=2)

colors = ('#5EBD3E', '#009CDF', '#973999')
for patch, color in zip(bp['boxes'], colors):
        patch.set_facecolor(color)
        
## change color and linewidth of the medians
for median in bp['medians']:
    median.set(color='#7f7f7f', linewidth=2)
plt.xticks((1, 2, 3), ['surface', 'core', 'interface'])
plt.ylabel("Shannon's Entropy")
plt.title('O75874')

# Save the figure
fig.savefig('o75874_box_shannon.png', bbox_inches='tight')
plt.show()

surfHist = tuple(dataDic[i][1] for i in surfDic if surfDic[i] == 1 and i in dataDic and i not in inter)
coreHist = tuple(dataDic[i][1] for i in surfDic if surfDic[i] == 0 and i in dataDic and i not in inter)
intrHist = tuple(dataDic[i][1] for i in surfDic if i in inter)


data_to_plot = (surfHist, coreHist, intrHist)
# Create a figure instance
fig = plt.figure(1, figsize=(9, 6))


plt.rcParams['lines.linewidth']=3
plt.rcParams['axes.facecolor']='white'
plt.rcParams['xtick.color']='gray'

# Create an axes instance
ax = fig.add_subplot(111)

# Create the boxplot
bp = ax.boxplot(data_to_plot, showfliers=False, patch_artist=True)

for cap in bp['caps']:
    cap.set(color='grey', linewidth=2)

colors = ('#5EBD3E', '#009CDF', '#973999')
for patch, color in zip(bp['boxes'], colors):
        patch.set_facecolor(color)
        
## change color and linewidth of the medians
for median in bp['medians']:
    median.set(color='#7f7f7f', linewidth=2)
plt.xticks((1, 2, 3), ['surface', 'core', 'interface'])
plt.ylabel('Evolution Rate')
plt.title('O75874')

# Save the figure
fig.savefig('o75874_box_ratio.png', bbox_inches='tight')
plt.show()

fig = plt.figure(1, figsize=(9, 6))
x = data["norm"]
y = data["entropy"]
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)
lx = np.arange(start=min(x), stop=max(x)+0.5, step=len(x)/1000)
ly = tuple(slope*i + intercept for i in lx)
plt.scatter(x,y, color='#3a3a3a')
plt.plot()
plt.plot(lx, ly, color='steelblue')
plt.title(code)
plt.xlabel('Evolution Rate')
plt.ylabel("Shannon's entropy")
fig.savefig('o75874_scatter.png', bbox_inches='tight')
plt.show()


for i in surfDic:
    if surfDic[i] == 1 and i not in inter:
        print('color green, resi', i)
    elif surfDic[i] == 0 and i not in inter:
        print('color blue, resi', i)
        
for i in inter:
    print('color purple, resi', i)
# Out:
# color green, resi 3
# color green, resi 4
# color green, resi 5
# color green, resi 6
# color green, resi 7
# color green, resi 8
# color blue, resi 9
# color blue, resi 10
# color blue, resi 11
# color blue, resi 12
# color blue, resi 13
# color blue, resi 14
# color blue, resi 15
# color blue, resi 16
# color blue, resi 17
# color blue, resi 18
# color blue, resi 19
# color green, resi 20
# color green, resi 21
# color blue, resi 22
# color blue, resi 23
# color green, resi 24
# color green, resi 25
# color blue, resi 26
# color blue, resi 27
# color green, resi 28
# color blue, resi 29
# color blue, resi 30
# color blue, resi 31
# color green, resi 32
# color green, resi 33
# color green, resi 34
# color blue, resi 35
# color green, resi 36
# color blue, resi 37
# color green, resi 38
# color green, resi 39
# color green, resi 40
# color green, resi 41
# color green, resi 42
# color blue, resi 43
# color blue, resi 44
# color blue, resi 45
# color blue, resi 46
# color green, resi 47
# color green, resi 48
# color blue, resi 49
# color green, resi 50
# color green, resi 51
# color green, resi 52
# color green, resi 53
# color green, resi 54
# color green, resi 55
# color blue, resi 56
# color blue, resi 57
# color green, resi 58
# color green, resi 59
# color blue, resi 60
# color blue, resi 61
# color green, resi 62
# color green, resi 63
# color blue, resi 64
# color green, resi 65
# color green, resi 66
# color green, resi 67
# color blue, resi 68
# color blue, resi 69
# color blue, resi 70
# color blue, resi 71
# color blue, resi 72
# color blue, resi 73
# color blue, resi 74
# color blue, resi 75
# color blue, resi 76
# color blue, resi 78
# color green, resi 79
# color green, resi 80
# color green, resi 81
# color blue, resi 82
# color green, resi 83
# color green, resi 84
# color green, resi 85
# color green, resi 86
# color green, resi 87
# color blue, resi 88
# color green, resi 89
# color green, resi 90
# color green, resi 91
# color blue, resi 92
# color green, resi 93
# color blue, resi 94
# color blue, resi 95
# color blue, resi 96
# color blue, resi 97
# color green, resi 98
# color blue, resi 99
# color blue, resi 100
# color blue, resi 101
# color green, resi 102
# color blue, resi 103
# color green, resi 104
# color blue, resi 105
# color blue, resi 106
# color blue, resi 107
# color blue, resi 108
# color blue, resi 109
